# %% [markdown]
# # DSC410 Joseph Aytch Project Milestone 2

# %% [markdown]
# ## Data source and Data Description

# %% [markdown]
# The dataset I decided to use is a precleaned fraud dataset from Kaggle.
#  https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud?resource=download
#
# The data has already been cleaned, transformed, and normalized. Since the data is apparently real data, the columns have had their name changed to protect the confidentiality of the customers.
#
# In a real-world scenario, we would hopefully have access to the real-time data, but would still need to follow confidentiality rules for the sake of the customers.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Open dataset from drive called creditcard_fraud_data.csv

df = pd.read_csv('/content/drive/MyDrive/Bellevue Docs/creditcard_fraud_data.csv')
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# pip install skimpy

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
from skimpy import skim
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 284807 │ │ float64     │ 30    │                                                          │
# │ │ Number of columns │ 31     │ │ int64       │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# ...

# %%
# Create a correlation heatmap for the dataset

corr = df.corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=False, cmap=sns.diverging_palette(220, 10, as_cmap=True))
plt.show()

# %% [markdown]
# ## Questions about the data
#
#     What types of variables are there in the dataset?
# The variables are unnamed but likely have to do with demographics, income, and other sensitive information. We do have Amount and class though, every class is likely numerical or ordinal converted into numbers.
#
#     What do their distributions look like?
# Most of the columns look relatively unskewed.
#
#     Do you have missing values?
# None.
#
#     Are there redundant features?
# No way of knowing without seeing the names of the columns, that said, since they are already cleaned, most redundant features.
#
#     What are the relationships between the main features?
# V1 to v28 all tie into what factors into a fraudulent purchase, but without seeing the columns we can't know really.
#
#     Do you observe outliers?
# Not any that stand out.
#
#     How do the different pairs of features correlate with one another?
# No significant correlations seem to exist in the data.
#
#     Do these correlations make sense?
# Hard to tell since we don't know which features are which.
#
#     What is the relationship between the features and the target?
# Without seeing the columns we can't know really.
#
#     Have you confirmed or rejected your hypothesis?
# Still in the process of forumulating one.
#
#     What do you know now that will inform the modeling strategy?
# I will experiment with different features on the model, seeing if certain features affect the model positively or negatively.
